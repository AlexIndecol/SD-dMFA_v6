# %% [markdown]
# # Tutorial: SD-dMFA Notebook Suite Index
#
# This index maps the dedicated notebook suite. Execute notebooks independently based on your task.

# %% [markdown]
# ## Recommended Reading Order
#
# 1. 01 Environment Setup and Repo Orientation
# 2. 02 Config Interfaces and Scenario Resolution
# 3. 03 Data Validation and Input QC
# 4. 04 Execution: Single Run, Batch, and Phases
# 5. 05 Output Inspection and Convergence Diagnostics
# 6. 06 Scenario Comparison, KPIs, and Analysis
# 7. 07 Plotting and Reporting Packages
# 8. 08 Calibration and Patch Lifecycle
# 9. 09 Realism Audit and Gate Triage
# 10. 10 Temporal Profiles, Ramps, and Scenario Authoring

# %%
from pathlib import Path
import json

root = Path.cwd().resolve()
nb_dir = root / "output" / "jupyter-notebook"
print("Notebook folder:", nb_dir)
for p in sorted(nb_dir.glob("*.ipynb")):
    print(" -", p.name)

# %% [markdown]
# ## Notebook Catalog

# %%
catalog = [
    ("01-environment-setup-and-repo-orientation.ipynb", "Environment and repo readiness"),
    ("02-config-interfaces-and-scenario-resolution.ipynb", "Config loading, precedence, slice resolution"),
    ("03-data-validation-and-input-qc.ipynb", "Registry + data quality checks"),
    ("04-execution-single-run-batch-and-phases.ipynb", "Operational run commands and run matrix"),
    ("05-output-inspection-and-convergence-diagnostics.ipynb", "Inspect summary, timeseries, convergence"),
    ("06-scenario-comparison-kpis-and-analysis.ipynb", "Comparative analysis and KPI slicing"),
    ("07-plotting-and-reporting-packages.ipynb", "Generate reproducible figure packages"),
    ("08-calibration-and-patch-lifecycle.ipynb", "Calibrate, promote, restore, verify"),
    ("09-realism-audit-and-gate-triage.ipynb", "Audit gates and intervention design"),
    ("10-temporal-profiles-ramps-and-scenario-authoring.ipynb", "Temporal forms and exogenous ramp authoring"),
    ("sd-dmfa-model-cookbook.ipynb", "Legacy all-in-one notebook (optional)"),
]
for name, desc in catalog:
    print(f"{name}: {desc}")

# %% [markdown]
# ## Execution Policy
#
# - Start with `DRY_RUN=True` when learning.
# - Enable heavy sections only when needed (`RUN_HEAVY`, `RUN_CALIBRATION`, `RUN_PLOTS`, `RUN_AUDIT`).
# - Keep run notes in markdown cells after each heavy execution.
